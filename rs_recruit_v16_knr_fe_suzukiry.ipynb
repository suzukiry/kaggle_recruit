# %% [markdown]
# # Test KNeighborsRegressor

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.model_selection import KFold, GridSearchCV, train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import StandardScaler
import time
# %matplotlib inline

import xgboost
from sklearn.neighbors import KNeighborsRegressor
from bayes_opt import BayesianOptimization

import warnings
warnings.filterwarnings("ignore")

# %%
### Thanks to Shinji Suzuki

# OS
import glob, re
from datetime import datetime
import pickle

# data science tool
import numpy as np
import pandas as pd
import datetime as dt


# machine learning
from sklearn import *
from xgboost import XGBRegressor
import xgboost as xgb
import lightgbm as lgb

# データの読み込み
# 事前にcalendar_dateをvisit_dataに変更しています。airとhpgで同じことですが、別名で使用されているようです。
data = {
    'tra': pd.read_csv('../../../mltestdata/05_recruit/air_visit_data.csv'),
    'as': pd.read_csv('../../../mltestdata/05_recruit/air_store_info.csv'),
    'hs': pd.read_csv('../../../mltestdata/05_recruit/hpg_store_info.csv'),
    'ar': pd.read_csv('../../../mltestdata/05_recruit/air_reserve.csv'),
    'hr': pd.read_csv('../../../mltestdata/05_recruit/hpg_reserve.csv'),
    'id': pd.read_csv('../../../mltestdata/05_recruit/store_id_relation.csv'),
    'tes': pd.read_csv('../../../mltestdata/05_recruit/sample_submission.csv'),
    'hol': pd.read_csv('../../../mltestdata/05_recruit/date_info.csv').rename(columns={'calendar_date':'visit_date'})
}

# それぞれのデータをマージするために、まずは、relation用のものをマージします
data['hr'] = pd.merge(data['hr'], data['id'], how = 'inner', on = ['hpg_store_id'])

for df in ['ar', 'hr']:
    data[df]['visit_datetime'] = pd.to_datetime(data[df]['visit_datetime'])
    data[df]['visit_datetime'] = data[df]['visit_datetime'].dt.date
    data[df]['reserve_datetime'] = pd.to_datetime(data[df]['reserve_datetime'])
    data[df]['reserve_datetime'] = data[df]['reserve_datetime'].dt.date
    data[df]['reserve_datetime_diff'] = data[df].apply(lambda r:(r['visit_datetime']- r['reserve_datetime']).days, axis = 1)
    tmp1 = data[df].groupby(['air_store_id', 'visit_datetime'], as_index =False)[['reserve_datetime_diff', 'reserve_visitors']].sum().rename(columns = {'visit_datetime':'visit_date', 'reserve_datetime_diff':'rs1', 'reserve_visitors':'rv1'})
    tmp2 = data[df].groupby(['air_store_id', 'visit_datetime'], as_index =False)[['reserve_datetime_diff', 'reserve_visitors']].mean().rename(columns = {'visit_datetime':'visit_date', 'reserve_datetime_diff':'rs2', 'reserve_visitors':'rv2'})
    data[df] = pd.merge(tmp1, tmp2, how = 'inner', on = ['air_store_id', 'visit_date'])

data['tra']['visit_date'] = pd.to_datetime(data['tra']['visit_date'])
data['tra']['dow'] = data['tra']['visit_date'].dt.dayofweek
data['tra']['year'] = data['tra']['visit_date'].dt.year
data['tra']['month'] = data['tra']['visit_date'].dt.month
data['tra']['visit_date'] = data['tra']['visit_date'].dt.date

data['tes']['visit_date'] = data['tes']['id'].map(lambda x: str(x).split('_')[2])
data['tes']['air_store_id'] = data['tes']['id'].map(lambda x: '_'.join(x.split('_')[:2]))
data['tes']['visit_date'] = pd.to_datetime(data['tes']['visit_date'])
data['tes']['dow'] = data['tes']['visit_date'].dt.dayofweek
data['tes']['year'] = data['tes']['visit_date'].dt.year
data['tes']['month'] = data['tes']['visit_date'].dt.month
data['tes']['visit_date'] = data['tes']['visit_date'].dt.date

unique_stores = data['tes']['air_store_id'].unique()

stores = pd.concat([pd.DataFrame({'air_store_id':unique_stores, 'dow':[i]*len(unique_stores)}) for i in range(7)], axis =0, ignore_index = True).reset_index(drop = True) 

#曜日だけでなく、月も追加
stores_m = pd.concat([pd.DataFrame({'air_store_id':unique_stores, 'month':[i]*len(unique_stores)}) for i in range(1,13)], axis =0, ignore_index = True).reset_index(drop = True)
stores = pd.merge(stores_m, stores,on=('air_store_id'), how='left')

tmp = data['tra'].groupby(['air_store_id', 'dow'], as_index = False)['visitors'].min().rename(columns = {'visitors':'min_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'dow'])
tmp = data['tra'].groupby(['air_store_id', 'dow'], as_index = False)['visitors'].mean().rename(columns = {'visitors':'mean_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'dow'])
tmp = data['tra'].groupby(['air_store_id', 'dow'], as_index = False)['visitors'].median().rename(columns = {'visitors':'median_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'dow'])
tmp = data['tra'].groupby(['air_store_id', 'dow'], as_index = False)['visitors'].max().rename(columns = {'visitors':'max_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'dow'])
tmp = data['tra'].groupby(['air_store_id', 'dow'], as_index = False)['visitors'].count().rename(columns = {'visitors':'count_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'dow'])

#曜日だけでなく、ID×月も追加
tmp = data['tra'].groupby(['air_store_id', 'month'], as_index = False)['visitors'].min().rename(columns = {'visitors':'m_min_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'month'])
tmp = data['tra'].groupby(['air_store_id', 'month'], as_index = False)['visitors'].mean().rename(columns = {'visitors':'m_mean_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'month'])
tmp = data['tra'].groupby(['air_store_id', 'month'], as_index = False)['visitors'].median().rename(columns = {'visitors':'m_median_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'month'])
tmp = data['tra'].groupby(['air_store_id', 'month'], as_index = False)['visitors'].max().rename(columns = {'visitors':'m_max_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'month'])
tmp = data['tra'].groupby(['air_store_id', 'month'], as_index = False)['visitors'].count().rename(columns = {'visitors':'m_count_visitors'})
stores = pd.merge(stores, tmp, how ='left', on = ['air_store_id', 'month'])

stores = pd.merge(stores, data['as'], how= "left", on = ['air_store_id'])

stores['air_genre_name'] = stores['air_genre_name'].map(lambda x: str(str(x).replace('/', ' ')))
stores['air_area_name'] = stores['air_area_name'].map(lambda x: str(str(x).replace('-', ' ')))

lbl = preprocessing.LabelEncoder()
for i in range(10):
    stores['air_genre_name' + str(i)] = lbl.fit_transform(stores['air_genre_name'].map(lambda x: str(str(x).split(' ')[i]) if len(str(x).split(' '))>i else ' '))
    stores['air_area_name' + str(i)] = lbl.fit_transform(stores['air_area_name'].map(lambda x: str(str(x).split(' ')[i]) if len(str(x).split(' '))>i else ' '))
stores['air_genre_name'] = lbl.fit_transform(stores['air_genre_name'])
stores['air_area_name'] = lbl.fit_transform(stores['air_area_name'])

#土日フラグ(day_of_week_1)と、休日前(holi_2)フラグを追加
data['hol']['day_of_week_1']= data['hol']['day_of_week'].replace(['Saturday', 'Sunday','Monday','Tuesday','Wednesday','Thursday','Friday'],['1', '1','0','0','0','0','0']).astype('int')
data['hol']['holi_2'] = data['hol'][['holiday_flg', 'day_of_week_1']].sum(axis = 1)
data['hol']['holi_2'] = data['hol']['holi_2'].apply( lambda x: 0 if x < 1 else 1 )
data['hol']['holi_2'] = data['hol']['holi_2'].shift(-1)
data['hol']['holi_2'] = data['hol']['holi_2'].fillna(1)
data['hol']['holi_2'] = data['hol']['holi_2'].astype('int')

data['hol']['visit_date'] = pd.to_datetime(data['hol']['visit_date'])
data['hol']['day_of_week'] = lbl.fit_transform(data['hol']['day_of_week'])
data['hol']['visit_date'] = data['hol']['visit_date'].dt.date
train = pd.merge(data['tra'], data['hol'], how ='left', on = ['visit_date'])
test = pd.merge(data['tes'], data['hol'], how ='left', on = ['visit_date'])

#曜日と月でmerge
train = pd.merge(train, stores, how ='left', on = ['air_store_id', 'dow','month'])
test = pd.merge(test, stores, how ='left', on = ['air_store_id', 'dow','month'])

#ID×休日前でのvisitorsの平均、中央値等を追加
tmp = train.groupby(['air_store_id','holi_2'], as_index = False)['visitors'].min().rename(columns = {'visitors':'h_min_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','holi_2'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','holi_2'])
tmp = train.groupby(['air_store_id','holi_2'], as_index = False)['visitors'].mean().rename(columns = {'visitors':'h_mean_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','holi_2'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','holi_2'])
tmp = train.groupby(['air_store_id','holi_2'], as_index = False)['visitors'].median().rename(columns = {'visitors':'h_median_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','holi_2'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','holi_2'])
tmp = train.groupby(['air_store_id','holi_2'], as_index = False)['visitors'].max().rename(columns = {'visitors':'h_max_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','holi_2'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','holi_2'])
tmp = train.groupby(['air_store_id','holi_2'], as_index = False)['visitors'].count().rename(columns = {'visitors':'h_count_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','holi_2'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','holi_2'])

for df in ['ar','hr']:
    train = pd.merge(train, data[df], how='left', on=['air_store_id','visit_date']) 
    test = pd.merge(test, data[df], how='left', on=['air_store_id','visit_date'])

train['id'] = train.apply(lambda r: '_'.join([str(r['air_store_id']), str(r['visit_date'])]), axis=1) 

train['total_reserve_sum'] = train['rv1_x'] + train['rv1_y']
train['total_reserve_mean'] = (train['rv2_x'] + train['rv2_y'])/2
train['total_reserve_dt_diff_mean'] = (train['rs2_x'] + train['rs2_y'])/2

test['total_reserve_sum'] = test['rv1_x'] + test['rv1_y']
test['total_reserve_mean'] = (test['rv2_x'] + test['rv2_y'])/2
test['total_reserve_dt_diff_mean'] = (test['rs2_x'] + test['rs2_y'])/2

train['date_int'] = train['visit_date'].apply(lambda x: x.strftime('%Y%m%d')).astype(int)
test['date_int'] = test['visit_date'].apply(lambda x: x.strftime('%Y%m%d')).astype(int)
train['var_max_lat'] = train['latitude'].max() - train['latitude']
train['var_max_long'] = train['longitude'].max() - train['longitude']
test['var_max_lat'] = test['latitude'].max() - test['latitude']
test['var_max_long'] = test['longitude'].max() - test['longitude']
train['lon_plus_lat'] = train['longitude'] + train['latitude'] 
test['lon_plus_lat'] = test['longitude'] + test['latitude']

lbl = preprocessing.LabelEncoder()
train['air_store_id2'] = lbl.fit_transform(train['air_store_id'])
test['air_store_id2']= lbl.fit_transform(test['air_store_id'])

train['lon_plus_lat'] = train['longitude'] + train['latitude'] 
test['lon_plus_lat'] = test['longitude'] + test['latitude']

col = [c for c in train if c not in ['id', 'air_store_id', 'visit_date', 'visitors']]
train = train.fillna(-1)
test = test.fillna(-1)

ntrain = train.shape[0]
ntest = test.shape[0]

all_data = pd.concat([train, test]) 

#指数移動平均の追加。これはなくても良いかも
#https://www.kaggle.com/c/recruit-restaurant-visitor-forecasting/discussion/46179#266344
#def calc_shifted_ewm(series, alpha, adjust=True):
#    return series.shift().ewm(alpha=alpha, adjust=adjust).mean()

#train['ewm'] = train.groupby(['air_store_id', 'dow']).apply(lambda g: calc_shifted_ewm(g['visitors'], 0.1)).sort_index(level=['air_store_id']).values

#以下、気象データの追加
df_air_store_weather_station = pd.read_csv('../../../mltestdata/05_recruit/air_store_info_with_nearest_active_station.csv')

cols = ['air_store_id', 'station_id', 'station_latitude', 'station_longitude', 'station_vincenty', 'station_great_circle']
all_data = pd.merge(all_data, df_air_store_weather_station[cols], on='air_store_id', how='left')

combine = all_data
filenames = []
df_weather = None
for station_id in combine['station_id'].unique():
    fn = f"../../../mltestdata/05_recruit/1-1-16_5-31-17_Weather/{station_id}.csv"
    if not fn in filenames:
        df = pd.read_csv(fn)
        df['station_id'] = station_id
        if df_weather is None:
            df_weather = df
        else:
            df_weather = pd.concat([df_weather, df])
        del df

        filenames.append(fn)
    else:
        continue

#欠損値を平均で穴埋め（median, ffillで試すも特に差は出なかった）
df_weather = df_weather.fillna(df_weather.mean())

df_weather = df_weather.rename(columns={'calendar_date': 'visit_date'})

df_weather['visit_date'] = pd.to_datetime(df_weather['visit_date'])
df_weather['visit_date'] = df_weather['visit_date'].dt.date

#なんとなく対数化
df_weather['precipitation'] = np.log1p(df_weather['precipitation'])

#使いそうなデータだけ結合（その他の気象データは試していません。特に意味はなし）
cols = ['station_id', 
    'visit_date', 
    'precipitation', 
    'hours_sunlight',
    'avg_temperature',
    'high_temperature',
    'low_temperature']

combine = pd.merge(combine, df_weather[cols], on=['station_id', 'visit_date'], how='left')

#降水量をカテゴリ化
def simplify_pre(df):
    df.precipitation = df.precipitation.fillna(0)
    bins = ( -1, 0.01, 2,  5)
    group_names = ['1', '2', '3']
    categories = pd.cut(df.precipitation, bins, labels=group_names)
    df.precipitation = categories
    return df

combine = simplify_pre(combine) 
all_data = combine 

#不要そうなデータを削除
drop_col =['station_id', 'station_latitude','station_longitude','station_vincenty', 'station_great_circle','hours_sunlight','high_temperature','low_temperature']
all_data = all_data.drop(drop_col, axis = 1)

train = all_data[:ntrain]
test = all_data[ntrain:]

#ID×降水量で平均、中央値等を追加
tmp = train.groupby(['air_store_id','precipitation'], as_index = False)['visitors'].min().rename(columns = {'visitors':'p_min_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','precipitation'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','precipitation'])

tmp = train.groupby(['air_store_id','precipitation'], as_index = False)['visitors'].mean().rename(columns = {'visitors':'p_mean_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','precipitation'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','precipitation'])

tmp = train.groupby(['air_store_id','precipitation'], as_index = False)['visitors'].median().rename(columns = {'visitors':'p_median_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','precipitation',])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','precipitation'])

tmp = train.groupby(['air_store_id','precipitation'], as_index = False)['visitors'].max().rename(columns = {'visitors':'p_max_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','precipitation'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','precipitation'])

tmp = train.groupby(['air_store_id','precipitation'], as_index = False)['visitors'].count().rename(columns = {'visitors':'p_count_visitors'})
train = pd.merge(train, tmp, how ='left', on = ['air_store_id','precipitation'])
test = pd.merge(test, tmp, how ='left', on = ['air_store_id','precipitation'])

#countをLabel Encoder化。なんとなく試してみたら結果が良かった。
lbl = preprocessing.LabelEncoder()
train['count_visitors'] = lbl.fit_transform(train['count_visitors']) 
test['count_visitors']= lbl.fit_transform(test['count_visitors'])
train['m_count_visitors'] = lbl.fit_transform(train['m_count_visitors'])
test['m_count_visitors']= lbl.fit_transform(test['m_count_visitors'])
train['h_count_visitors'] = lbl.fit_transform(train['h_count_visitors'])
test['h_count_visitors']= lbl.fit_transform(test['h_count_visitors'])
train['p_count_visitors'] = lbl.fit_transform(train['p_count_visitors'])
test['p_count_visitors']= lbl.fit_transform(test['p_count_visitors'])

# GW flag
combine = [train, test]
gw_list = ['2016-04-29','2016-04-30','2016-05-01','2016-05-02','2016-05-03','2016-05-04','2016-05-05','2017-04-29','2017-04-30','2017-05-01','2017-05-02','2017-05-03','2017-05-04','2017-05-05']
post_gw_list=['2016-05-06']
train['gw_flg'] = 0
train['post_gw_flg'] = 0
test['gw_flg'] = 0
test['post_gw_flg'] = 0
update_gw_list = [["0" for i in range(3)] for j in range(len(gw_list))]
update_post_gw_list = [["0" for i in range(3)] for j in range(len(post_gw_list))]

from datetime import date
for index, gw_date in enumerate(gw_list):
    temp_list = gw_date.split("-")
    for col_i, temp_figure in enumerate(temp_list):
        update_gw_list[index][col_i]=int(temp_figure)
        
    #print("{}  {}  {}".format(update_list[index][0],update_list[index][1],update_list[index][2]))
    
for index, gw_date in enumerate(post_gw_list):
    temp_list = gw_date.split("-")
    for col_i, temp_figure in enumerate(temp_list):
        update_post_gw_list[index][col_i]=int(temp_figure)

for dataset in combine:
    for index in range(len(update_gw_list)):
        dataset.loc[dataset.visit_date == date(update_gw_list[index][0],update_gw_list[index][1],update_gw_list[index][2]), 'gw_flg'] = 1
        
for dataset in combine:
    for index in range(len(update_post_gw_list)):
        dataset.loc[dataset.visit_date == date(update_post_gw_list[index][0],update_post_gw_list[index][1],update_post_gw_list[index][2]), 'post_gw_flg'] = 1

# %%
train['precipitation'] = train['precipitation'].values.astype(float)
test['precipitation'] = test['precipitation'].values.astype(float)

# Handle NaN
train = train.fillna(-1)
test = test.fillna(-1)

# %%
tra = train.copy()
tes = test.copy()

import datetime as dt
from datetime import datetime

#tra = pd.read_csv('/Users/suzukishinji/kaggle/recluit/air_visit_data.csv')
#tes = pd.read_csv('/Users/suzukishinji/kaggle/recluit/sample_submission-3.csv')

#countで試してみましたが、「2016年初めからデータはあるものの営業日の少ないお店」と「データは途中からだけど営業日の多い店」が混じるため、2016/1~2016/6に営業していた店と営業していないお店という分け方をしてみました。

tra['visit_date'] = pd.to_datetime(tra['visit_date'])
tra['visit_date'] = pd.to_datetime(tra['visit_date'])
tra['dow'] = tra['visit_date'].dt.dayofweek
tra['year'] = tra['visit_date'].dt.year
tra['month'] = tra['visit_date'].dt.month
tra['visit_date'] = tra['visit_date'].dt.date

#2016/1~2016/6に営業しているお店は316店舗でした。
year_2016 = tra[tra['year'] == 2016]
month_1 = year_2016[year_2016['month'] == 1]
month_2 = year_2016[year_2016['month'] == 2]
month_3 = year_2016[year_2016['month'] == 3]
month_4 = year_2016[year_2016['month'] == 4]
month_5 = year_2016[year_2016['month'] == 5]
month_6 = year_2016[year_2016['month'] == 6]
tra_store_316_6 = pd.concat([month_1,month_2,month_3,month_4,month_5,month_6])

id = list(tra_store_316_6['air_store_id'].values.flatten())

#trainデータから2016/1~2016/6に営業しているお店の全期間を抜き出したもの。
#trainデータから上記を除いたものが513店舗。
tra_store_316_all = tra[tra['air_store_id'].isin(id)]
tra_store_513 = tra[~tra['air_store_id'].isin(id)] # これはNOTなんだ。

tes['visit_date'] = tes['id'].map(lambda x: str(x).split('_')[2])
tes['air_store_id'] = tes['id'].map(lambda x: '_'.join(x.split('_')[:2]))
tes['visit_date'] = pd.to_datetime(tes['visit_date'])
tes['dow'] = tes['visit_date'].dt.dayofweek
tes['year'] = tes['visit_date'].dt.year
tes['month'] = tes['visit_date'].dt.month
tes['visit_date'] = tes['visit_date'].dt.date

#testデータから2016/1~2016/6に営業しているお店の全期間を抜き出したもの。
#testデータから上記を除いたものが513店舗。
tes_store_316 = tes[tes['air_store_id'].isin(id)]
tes_store_513 = tes[~tes['air_store_id'].isin(id)]

#使うのは①2016/1~2016/6の期間のデータ、②2016/1~2016/6に営業していたお店の全期間のデータ、③途中からの513店舗のデータ。
#tra_store_316_6[['air_store_id', 'visit_date','visitors']].to_csv('tra_store_316_6.csv', index = False)
#tra_store_316_all[['air_store_id', 'visit_date','visitors']].to_csv('tra_store_316_all.csv', index = False)
#tra_store_513[['air_store_id', 'visit_date','visitors']].to_csv('tra_store_513.csv', index = False)

#使うのは①2016/1~2016/6の期間のデータ、②2016/1~2016/6に営業していたお店の全期間のデータ、③途中からの513店舗のデータ。
tra_store_316_6.to_csv('tra_store_316_6.csv', index = False)
tra_store_316_all.to_csv('tra_store_316_all.csv', index = False)
tra_store_513.to_csv('tra_store_513.csv', index = False)

#テストデータは期間で分けずに最初からの316店舗と途中からの513店舗
#tes_store_316[['id','visitors']].to_csv('tes_store_316.csv', index = False)
#tes_store_513[['id','visitors']].to_csv('tes_store_513.csv', index = False)

tes_store_316.to_csv('tes_store_316.csv', index = False)
tes_store_513.to_csv('tes_store_513.csv', index = False)

tra_316_6 = pd.read_csv('./tra_store_316_6.csv') # 316 for period 1 (first 6 months)
tra_316_all = pd.read_csv('./tra_store_316_all.csv') # 316 for period 1 & 2
tra_513 = pd.read_csv('./tra_store_513.csv') # 513 for period 2 (expect first 6 months)
tes_316 = pd.read_csv('./tes_store_316.csv') # 316 only
tes_513 = pd.read_csv('./tes_store_513.csv') # 513 only

#出力されているか確認。（①と③はくっつけて使う）
print("Total train: "+str(tra.shape))
print("316 for period 1: "+str(tra_316_6.shape))
print("316 for period 1 & 2: "+str(tra_316_all.shape)+" <=== To be used")
print("513 for period 2 "+str(tra_513.shape))
tra_513_316 = pd.concat([tra_316_6, tra_513], ignore_index=True)
print("316 for period 1 + 513 for period 2 "+str(tra_513_316.shape)+" <=== To be used"+"\n")
print("Total test: "+str(tes.shape))
print("test with 316"+str(tes_316.shape))
print("test with 513"+str(tes_513.shape))

train_1 = tra_316_all.copy()
test_1 = tes_316.copy()

train_2 = tra_513_316.copy()
test_2 = tes_513.copy()

y_1 = train_1.visitors

drop_cols=['visitors','air_store_id','visit_date','id']
train_1=train_1.drop(drop_cols, axis=1)
test_1=test_1.drop(drop_cols, axis=1)

y_2 = train_2.visitors

train_2=train_2.drop(drop_cols, axis=1)
test_2=test_2.drop(drop_cols, axis=1)
# Out:
# Total train: (252108, 75)
# 316 for period 1: (47699, 75)
# 316 for period 1 & 2: (126700, 75) <=== To be used
# 513 for period 2 (125408, 75)
# 316 for period 1 + 513 for period 2 (173107, 75) <=== To be used
#
# Total test: (32019, 75)
# test with 316(12207, 75)
# test with 513(19812, 75)

# %% [markdown]
# ## KNeighborsRegressor

# %% [markdown]
# __Define utility functions__

# %%
#Define a evaluation function

def rmsle(preds, true):
    rmsle = np.sqrt(mean_squared_error(np.log1p(true), np.log1p(preds)))
    return float(rmsle)

# %%
#Define a evaluation matrix 
from sklearn.metrics.scorer import make_scorer
RMSLE = make_scorer(rmsle)

# %%
# Define a function for comparing predictions and true data.
def compare_result(preds, true):
    compare = pd.DataFrame({"test_id": true.index,
                           "real_cost": true,
                           "pred_cost": preds})
    compare = compare[["test_id", "real_cost", "pred_cost"]].reset_index(drop=True)
    
    compare["error_percent_(%)"] = np.abs(compare.real_cost - compare.pred_cost) / compare.real_cost * 100
    
    return compare

# %% [markdown]
# __Cross validation with KNeighborsRegressor__

# %%
def cross_validate_sklearn(clf, x_train, y_train , x_test, kf,scale=False, verbose=True, scoreonly=False):
    start_time=time.time()
    
    # initialise the size of out-of-fold train an test prediction
    train_pred = np.zeros((x_train.shape[0]))
    test_pred = np.zeros((x_test.shape[0]))

    # self-defined eval metric
    # f(preds: array, train_data: Dataset) -> name: string, value: array, is_higher_better: bool
    # binary error
    def feval_rmsle(preds, train_data):
        preds = np.expm1(preds)
        true = np.expm1(train_data.get_label())
        #return 'rmsle', rmsle(true, preds), False

        return 'rmsle', rmsle(preds, true), False
    
    # use the kfold object to generate the required folds
    for i, (train_index, val_index) in enumerate(kf.split(x_train, y_train)):
        # generate training folds and validation fold
        x_train_kf, x_val_kf = x_train.loc[train_index, :], x_train.loc[val_index, :]

        #y_train_kf, y_val_kf = y_train[train_index], y_train[test_index]
        y_train_kf, y_val_kf = np.log1p(y_train[train_index]), np.log1p(y_train[val_index])
        x_test_kf=x_test.copy()

        # perform scaling if required i.e. for linear algorithms
        if scale:
            scaler = StandardScaler().fit(x_train_kf.values)
            x_train_kf_values = scaler.transform(x_train_kf.values)
            x_val_kf_values = scaler.transform(x_val_kf.values)
            x_test_values = scaler.transform(x_test.values)
        else:
            x_train_kf_values = x_train_kf.values
            x_val_kf_values = x_val_kf.values
            x_test_values = x_test.values
        
        # fit the input classifier and perform prediction.
        clf.fit(x_train_kf_values, y_train_kf.values)

        #val_pred=clf.predict_proba(x_val_kf_values)[:,1]
        val_pred=np.expm1(clf.predict(x_val_kf_values))
        #train_pred[test_index] += val_pred
        train_pred[val_index] += val_pred

        #y_test_preds = clf.predict_proba(x_test_values)[:,1]
        y_test_preds = np.expm1(clf.predict(x_test_values))
        test_pred += y_test_preds

        #fold_auc = roc_auc_score(y_val_kf.values, val_pred)
        #fold_gini_norm = auc_to_gini_norm(fold_auc)
        fold_rmsle = rmsle(train_pred[val_index],np.expm1(y_val_kf.values))

        if verbose:
            print('fold cv {} RMSLE score is {:.6f}'.format(i, fold_rmsle))

    test_pred /= kf.n_splits

    #cv_auc = roc_auc_score(y_train, train_pred)
    #cv_gini_norm = auc_to_gini_norm(cv_auc)
    cv_score = rmsle(train_pred, y_train)
    
    if verbose:
        print('cv RMSLE score is {:.6f}'.format(cv_score))
        end_time = time.time()
        print("it takes %.3f seconds to perform cross validation" % (end_time - start_time))

    if scoreonly:
        return cv_score
    else:
        return cv_score, train_pred, test_pred

# %% [markdown]
# # 1. Modeling based on train_1

# %%
kf=StratifiedKFold(n_splits=3, shuffle=True, random_state=2018)

# Cluster 7 with scaling
knr = KNeighborsRegressor(n_jobs=-1, n_neighbors=7)

outcomes =cross_validate_sklearn(knr, train_1, y_1 ,test_1, kf, scale=True, verbose=True)

knr_cv=outcomes[0]
knr_train_pred=outcomes[1]
knr_test_pred=outcomes[2]

knr_train_pred_df=pd.DataFrame(columns=['visitors'], data=knr_train_pred)
knr_test_pred_df=pd.DataFrame(columns=['visitors'], data=knr_test_pred)
# Out:
# fold cv 0 RMSLE score is 0.517093
# fold cv 1 RMSLE score is 0.519778
# fold cv 2 RMSLE score is 0.520082
# cv RMSLE score is 0.518985
# it takes 405.373 seconds to perform cross validation

# %% [markdown]
# __GridSearch__

# %%
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

scoring_fnc=make_scorer(rmse)

# %%
knr = KNeighborsRegressor(n_jobs=-1, n_neighbors=7)

# %%
#Hyper Parameters Set
params = {'n_neighbors':[7],
          'leaf_size':[2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree'],#,'brute'
          'n_jobs':[-1]}
#Making models with hyper parameters sets

model1 = GridSearchCV(knr, param_grid=params, n_jobs=1,scoring=scoring_fnc,cv=10,verbose=3)
#Learning
model1.fit(train_1,np.log1p(y_1))
#The best hyper parameters set
print("Best Hyper Parameters:\n",model1.best_params_)
#Prediction
prediction=model1.predict(test_1)
#importing the metrics module

from sklearn import metrics
#evaluation(Accuracy)
#print("Accuracy:",metrics.accuracy_score(prediction,test_y))
#evaluation(Confusion Metrix)
#print("Confusion Metrix:\n",metrics.confusion_matrix(prediction,test_y))
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166879433988375, total=  12.3s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   54.0s remaining:    0.0s
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649732115441805, total=  10.2s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.9min remaining:    0.0s
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511698619277717, total=   9.6s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001407228580765, total=   5.9s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523961416773362, total=   9.6s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212472201062654, total=   9.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6472994089243909, total=  10.6s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654850178828993, total=   9.7s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.650305098082415, total=   9.8s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263324593555684, total=   8.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.716054934508717, total=   9.1s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.664482219909168, total=  10.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505053884795854, total=   8.9s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991897780175342, total=   5.4s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6524125996509881, total=   9.5s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.721609659850466, total=   8.3s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464289706628943, total=   9.6s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650080540624819, total=   9.9s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502107872937329, total=   9.7s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258255526891338, total=   7.8s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166879433988375, total=   9.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649732115441805, total=   9.8s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511698619277717, total=   8.9s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001407228580765, total=   5.3s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523961416773362, total=   9.5s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212472201062654, total=   8.2s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6472994089243909, total=   9.5s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654850178828993, total=   9.5s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.650305098082415, total=   9.8s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263324593555684, total=   8.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.716054934508717, total=   9.1s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.664482219909168, total=   9.8s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505053884795854, total=   9.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991897780175342, total=   5.3s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6524125996509881, total=   9.3s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.721609659850466, total=   7.9s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464289706628943, total=   9.4s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650080540624819, total=   9.2s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502107872937329, total=   9.2s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258255526891338, total=   7.8s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166680961054036, total=   7.7s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649650969174633, total=   8.4s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511796451663431, total=   7.4s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001392728360349, total=   5.5s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6524227544510623, total=   8.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212714350787895, total=   7.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6473004007227129, total=   8.4s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654806863766798, total=  10.2s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6503169522157135, total=  10.8s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263378375592622, total=   6.9s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7160358450210924, total=   7.8s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6644740899953098, total=   8.6s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505151034080824, total=   7.7s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991883191952919, total=   4.5s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.652438703000635, total=   8.3s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7216335294110574, total=   7.2s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464288268060812, total=   8.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650037664730593, total=   9.1s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502226986492237, total=   8.9s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258307072043813, total=   7.5s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166868945612721, total=   7.9s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649663697661763, total=   8.0s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511858257980317, total=   8.9s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001167703793261, total=   9.8s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523823665113345, total=   9.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.721267962699528, total=   7.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6472840400411164, total=   9.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.665480702494218, total=   7.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6503153698506723, total=   7.9s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263323561886389, total=   6.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7160539271207657, total=   8.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6644756424891647, total=   8.9s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505210952681197, total=   7.5s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991666926775961, total=   8.8s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6523990638624878, total=   9.4s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7216302747410701, total=   7.5s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464127337933832, total=  11.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650039525987517, total=   9.7s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.650217986780352, total=   9.3s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258256440660913, total=   8.2s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166868945612721, total=   8.7s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649663697661763, total=   8.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511858257980317, total=   7.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001167703793261, total=   8.0s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523823665113345, total=   9.8s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.721267962699528, total=   7.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6472840400411164, total=  10.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.665480702494218, total=   6.2s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6503153698506723, total=   8.3s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263323561886389, total=   6.5s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7160539271207657, total=   8.1s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6644756424891647, total=   8.3s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505210952681197, total=   6.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991666926775961, total=   6.6s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6523990638624878, total=   7.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7216302747410701, total=   6.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464127337933832, total=   7.4s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650039525987517, total=   6.9s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.650217986780352, total=   7.1s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258256440660913, total=   6.4s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166763443710082, total=   7.5s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649769729088614, total=   7.8s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511500940639177, total=   7.3s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001341474659162, total=   7.0s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523804660537988, total=   8.0s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212443414827022, total=   6.8s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6473130871011064, total=   8.3s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654791343577875, total=   7.4s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6503399499279451, total=   8.3s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263324397203353, total=   8.4s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7160439299667773, total=   9.4s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6644868467777127, total=   7.8s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6504856125693057, total=   7.1s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.699183935183183, total=   7.9s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.65239746598997, total=   9.2s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7216074026697427, total=   6.9s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464417866298633, total=   8.7s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650023788161147, total=   8.0s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502419994988555, total=   8.9s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258256912053132, total=   6.6s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166879433988375, total=   9.0s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649732115441805, total=   9.7s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511698619277717, total=   8.6s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001407228580765, total=   5.5s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523961416773362, total=  11.7s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212472201062654, total=   9.2s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6472994089243909, total=  11.3s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654850178828993, total=   9.5s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.650305098082415, total=  14.1s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263324593555684, total=   9.5s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.716054934508717, total=  11.5s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.664482219909168, total=   9.8s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505053884795854, total=  11.8s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991897780175342, total=   5.6s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6524125996509881, total=   9.4s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.721609659850466, total=   9.7s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464289706628943, total=  10.6s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650080540624819, total=   9.3s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502107872937329, total=   9.3s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258255526891338, total=   7.7s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166879433988375, total=  11.3s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649732115441805, total=   9.8s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511698619277717, total=  10.7s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001407228580765, total=   5.9s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6523961416773362, total=   9.2s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212472201062654, total=   7.9s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6472994089243909, total=  10.5s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654850178828993, total=  11.7s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.650305098082415, total=  12.4s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263324593555684, total=   9.8s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.716054934508717, total=  14.3s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.664482219909168, total=  11.1s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505053884795854, total=  11.0s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991897780175342, total=   7.4s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6524125996509881, total=  11.6s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.721609659850466, total=   7.8s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464289706628943, total=  10.9s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650080540624819, total=  11.4s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502107872937329, total=  12.2s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258255526891338, total=   8.9s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7166680961054036, total=   8.9s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6649650969174633, total=  10.5s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6511796451663431, total=   8.0s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7001392728360349, total=   4.5s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6524227544510623, total=   8.3s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7212714350787895, total=   8.2s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6473004007227129, total=   9.4s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6654806863766798, total=   9.2s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6503169522157135, total=  11.4s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.7263378375592622, total=   7.7s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7160358450210924, total=   7.7s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6644740899953098, total=   9.0s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6505151034080824, total=   7.5s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6991883191952919, total=   4.6s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.652438703000635, total=   7.5s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7216335294110574, total=   7.3s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6464288268060812, total=   8.1s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6650037664730593, total=   8.1s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6502226986492237, total=   7.9s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.7258307072043813, total=   8.5s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 155.4min finished
# Best Hyper Parameters:
#  {'algorithm': 'auto', 'leaf_size': 5, 'n_jobs': -1, 'n_neighbors': 7, 'weights': 'uniform'}

# %%
kf=StratifiedKFold(n_splits=10, shuffle=True, random_state=2018)

# Cluster 7 with scaling
knr = KNeighborsRegressor(n_jobs=-1, n_neighbors=7,algorithm='auto', leaf_size=5, weights= 'uniform')

outcomes =cross_validate_sklearn(knr, train_1, y_1 ,test_1, kf, scale=True, verbose=True)

knr_cv=outcomes[0]
knr_train_1_pred=outcomes[1]
knr_test_1_pred=outcomes[2]

knr_train_1_pred_df=pd.DataFrame(columns=['visitors'], data=knr_train_1_pred)
knr_test_1_pred_df=pd.DataFrame(columns=['visitors'], data=knr_test_1_pred)
# Out:
# fold cv 0 RMSLE score is 0.522621
# fold cv 1 RMSLE score is 0.510737
# fold cv 2 RMSLE score is 0.512806
# fold cv 3 RMSLE score is 0.513560
# fold cv 4 RMSLE score is 0.514405
# fold cv 5 RMSLE score is 0.512560
# fold cv 6 RMSLE score is 0.514044
# fold cv 7 RMSLE score is 0.515008
# fold cv 8 RMSLE score is 0.512395
# fold cv 9 RMSLE score is 0.511969
# cv RMSLE score is 0.514026
# it takes 1318.535 seconds to perform cross validation

# %% [markdown]
# # 2. Modeling based on train_2

# %%
kf=StratifiedKFold(n_splits=3, shuffle=True, random_state=2018)

# Cluster 7 with scaling
knr = KNeighborsRegressor(n_jobs=-1, n_neighbors=7)

outcomes =cross_validate_sklearn(knr, train_2, y_2 ,test_2, kf, scale=True, verbose=True)

knr_cv=outcomes[0]
knr_train_pred=outcomes[1]
knr_test_pred=outcomes[2]

knr_train_pred_df=pd.DataFrame(columns=['visitors'], data=knr_train_pred)
knr_test_pred_df=pd.DataFrame(columns=['visitors'], data=knr_test_pred)
# Out:
# fold cv 0 RMSLE score is 0.524019
# fold cv 1 RMSLE score is 0.524836
# fold cv 2 RMSLE score is 0.519137
# cv RMSLE score is 0.522672
# it takes 762.176 seconds to perform cross validation

# %% [markdown]
# __GridSearch__

# %%
from sklearn.metrics import mean_squared_error, r2_score, make_scorer

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

scoring_fnc=make_scorer(rmse)

# %%
knr = KNeighborsRegressor(n_jobs=-1, n_neighbors=7)

# %%
#Hyper Parameters Set
params = {'n_neighbors':[7],
          'leaf_size':[2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree'],#,'brute'
          'n_jobs':[-1]}
#Making models with hyper parameters sets

model1 = GridSearchCV(knr, param_grid=params, n_jobs=1,scoring=scoring_fnc,cv=10,verbose=3)
#Learning
model1.fit(train_2,np.log1p(y_2))
#The best hyper parameters set
print("Best Hyper Parameters:\n",model1.best_params_)
#Prediction
prediction=model1.predict(test_2)
#importing the metrics module

from sklearn import metrics
#evaluation(Accuracy)
#print("Accuracy:",metrics.accuracy_score(prediction,test_y))
#evaluation(Confusion Metrix)
#print("Confusion Metrix:\n",metrics.confusion_matrix(prediction,test_y))
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328097148454914, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.7min remaining:    0.0s
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500570872371122, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  5.1min remaining:    0.0s
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.5min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602542708062611, total=   9.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921850879538209, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534881491537456, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.62567160871068, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572208175559461, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.644253069024321, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400443752249113, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320495224616971, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494596124643887, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598712749141906, total=   9.2s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6915124310490649, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.653724792532095, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6250666308753109, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572412915140955, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.643850918783905, total= 1.6min
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394726119967334, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328095012256143, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500430470234098, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602733436501432, total=   7.6s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921728037988442, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534511458290533, total= 1.5min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6257130355882105, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572293432160582, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442520952099692, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400557681656396, total= 1.5min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320493105079891, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494456073516744, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.7min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598900969513062, total=   8.2s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6915004285007126, total= 1.5min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6536900227989153, total= 1.5min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6251070893130072, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572498809140219, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438502436788184, total= 1.6min
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394844241122615, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328095012256143, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500404366367577, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602521813764404, total=   6.4s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921701929728239, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534739418500364, total= 1.5min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6256813981424157, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.657228088514248, total= 1.5min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442576947461837, total= 1.5min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400402582524435, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320493105079891, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494431181193319, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.659869300852006, total=   6.3s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6914979876729558, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.653711081336383, total= 1.5min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6250761452952189, total= 1.6min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572487109922011, total= 1.5min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438561076945009, total= 1.5min
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394689121535184, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328097148454914, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500402732592546, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602730894659646, total=   8.8s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921537611250625, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534572689115377, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6256848503792032, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572374954855992, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442596614140562, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400486549376363, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320495224616971, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494429530290142, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598894364404205, total=   8.5s
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6914829860613219, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6536956620774442, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6250789556614935, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572578106875289, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438578888043295, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394774273810786, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328097148454914, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500401857955428, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602640793579735, total=   9.0s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921529321254456, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534397690466851, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6256778072552581, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572477174629161, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442554466248088, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400405412030856, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320495224616971, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494428627843852, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598804645466495, total=   9.0s
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.691482294341473, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6536785203038624, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.625071132676784, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572689581584737, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438539942909145, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394701046827669, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328095012256143, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500434894639022, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489749282220533, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602605881373369, total=   9.7s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921630580539133, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534628267684397, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6256917116948926, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572435192518312, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442571372312971, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400564286435877, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320493105079891, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494459959964496, total= 1.5min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474185945882196, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598772280276018, total=   9.7s
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.691491951685576, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6537000698928994, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6250850142267228, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572635741812994, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438555734901811, total= 1.6min
# [CV] algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394844978334037, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328097148454914, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500570872371122, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602542708062611, total=   9.0s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921850879538209, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534881491537456, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.62567160871068, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572208175559461, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.644253069024321, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400443752249113, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320495224616971, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494596124643887, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598712749141906, total=   9.1s
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6915124310490649, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.653724792532095, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6250666308753109, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572412915140955, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.643850918783905, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394726119967334, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328095012256143, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500430470234098, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602733436501432, total=   7.6s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921728037988442, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534511458290533, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6257130355882105, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6572293432160582, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442520952099692, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400557681656396, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320493105079891, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494456073516744, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6598900969513062, total=   7.6s
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6915004285007126, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6536900227989153, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6251070893130072, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572498809140219, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438502436788184, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394844241122615, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6328095012256143, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6500404366367577, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6489715333662559, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6602521813764404, total=   6.3s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6921701929728239, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6534739418500364, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6256813981424157, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.657228088514248, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6442576947461837, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.6400402582524435, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6320493105079891, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6494431181193319, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6474155786977563, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.659869300852006, total=   6.3s
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6914979876729558, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.653711081336383, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6250761452952189, total= 1.6min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6572487109922011, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6438561076945009, total= 1.5min
# [CV] algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=kd_tree, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.6394689121535184, total= 1.6min
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 406.0min finished
# Best Hyper Parameters:
#  {'algorithm': 'auto', 'leaf_size': 3, 'n_jobs': -1, 'n_neighbors': 7, 'weights': 'uniform'}

# %%
kf=StratifiedKFold(n_splits=10, shuffle=True, random_state=2018)

# Cluster 7 with scaling
knr = KNeighborsRegressor(n_jobs=-1, n_neighbors=7,algorithm='auto', leaf_size=3, weights= 'uniform')

outcomes =cross_validate_sklearn(knr, train_2, y_2 ,test_2, kf, scale=True, verbose=True)

knr_cv=outcomes[0]
knr_train_2_pred=outcomes[1]
knr_test_2_pred=outcomes[2]

knr_train_2_pred_df=pd.DataFrame(columns=['visitors'], data=knr_train_2_pred)
knr_test_2_pred_df=pd.DataFrame(columns=['visitors'], data=knr_test_2_pred)
# Out:
# fold cv 0 RMSLE score is 0.525873
# fold cv 1 RMSLE score is 0.521168
# fold cv 2 RMSLE score is 0.516966
# fold cv 3 RMSLE score is 0.517737
# fold cv 4 RMSLE score is 0.511108
# fold cv 5 RMSLE score is 0.517549
# fold cv 6 RMSLE score is 0.519370
# fold cv 7 RMSLE score is 0.517179
# fold cv 8 RMSLE score is 0.510698
# fold cv 9 RMSLE score is 0.513924
# cv RMSLE score is 0.517184
# it takes 3404.632 seconds to perform cross validation

# %% [markdown]
# # Saving data

# %%
_tes_316 = tes_316.drop(["visitors"],axis=1)
_tes_513 = tes_513.drop(["visitors"],axis=1)

# %%
lv1_knr_train_1_pred = knr_train_1_pred_df.copy()
lv1_knr_train_1_pred.to_csv('lv1_knr_train_1_pred.csv', index=False)

lv1_knr_test_1_pred = knr_test_1_pred_df.copy()
lv1_knr_test_1_pred.to_csv('lv1_knr_test_1_pred.csv', index=False)

_tes_316 = pd.concat([_tes_316,lv1_knr_test_1_pred], axis=1)

lv1_knr_train_2_pred = knr_train_2_pred_df.copy()
lv1_knr_train_2_pred.to_csv('lv1_knr_train_2_pred.csv', index=False)

lv1_knr_test_2_pred = knr_test_2_pred_df.copy()
lv1_knr_test_2_pred.to_csv('lv1_knr_test_2_pred.csv', index=False)

_tes_513 = pd.concat([_tes_513,lv1_knr_test_2_pred], axis=1)

knr_test_pred_df = pd.concat([_tes_316,_tes_513])

sub_ = knr_test_pred_df[['id','visitors']].copy()

sub_ = sub_.sort_values(by=['id'])

# %% [markdown]
# # Submission

# %%
sub_.to_csv('submission_rs_recruit_v16_knr_fe_suzukiry_01.csv', index=False)
print('Finished.')
# knr
# fe
# bopt
# train data separation
# LB: ---
# Out:
# Finished.

# %% [markdown]
# # Last work with weight

# %%
sub1 = sub_.copy()

# %%
# from hklee
# https://www.kaggle.com/zeemeen/weighted-mean-comparisons-lb-0-497-1st/code
dfs = { re.search('/([^/\.]*)\.csv', fn).group(1):
    pd.read_csv(fn)for fn in glob.glob('../../../mltestdata/05_recruit/*.csv')}

for k, v in dfs.items(): locals()[k] = v

wkend_holidays = date_info.apply(
    (lambda x:(x.day_of_week=='Sunday' or x.day_of_week=='Saturday') and x.holiday_flg==1), axis=1)
date_info.loc[wkend_holidays, 'holiday_flg'] = 0
date_info['weight'] = ((date_info.index + 1) / len(date_info)) ** 5  

visit_data = air_visit_data.merge(date_info, left_on='visit_date', right_on='calendar_date', how='left')
visit_data.drop('calendar_date', axis=1, inplace=True)
visit_data['visitors'] = visit_data.visitors.map(pd.np.log1p)

wmean = lambda x:( (x.weight * x.visitors).sum() / x.weight.sum() )
visitors = visit_data.groupby(['air_store_id', 'day_of_week', 'holiday_flg']).apply(wmean).reset_index()
visitors.rename(columns={0:'visitors'}, inplace=True) # cumbersome, should be better ways.

sample_submission['air_store_id'] = sample_submission.id.map(lambda x: '_'.join(x.split('_')[:-1]))
sample_submission['calendar_date'] = sample_submission.id.map(lambda x: x.split('_')[2])
sample_submission.drop('visitors', axis=1, inplace=True)
sample_submission = sample_submission.merge(date_info, on='calendar_date', how='left')
sample_submission = sample_submission.merge(visitors, on=[
    'air_store_id', 'day_of_week', 'holiday_flg'], how='left')

missings = sample_submission.visitors.isnull()
sample_submission.loc[missings, 'visitors'] = sample_submission[missings].merge(
    visitors[visitors.holiday_flg==0], on=('air_store_id', 'day_of_week'), 
    how='left')['visitors_y'].values

missings = sample_submission.visitors.isnull()
sample_submission.loc[missings, 'visitors'] = sample_submission[missings].merge(
    visitors[['air_store_id', 'visitors']].groupby('air_store_id').mean().reset_index(), 
    on='air_store_id', how='left')['visitors_y'].values

sample_submission['visitors'] = sample_submission.visitors.map(pd.np.expm1)
sub2 = sample_submission[['id', 'visitors']].copy()
sub_merge = pd.merge(sub1, sub2, on='id', how='inner')

# %%
sub_merge['visitors'] = (sub_merge['visitors_x'] + sub_merge['visitors_y']* 1.1)/2
sub_merge[['id', 'visitors']].to_csv('submission_rs_recruit_v16_knr_fe_suzukiry_02.csv', index=False)
# knr
# fe
# bopt
# train data separation
# LB: ---
